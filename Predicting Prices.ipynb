# %% [markdown]
# # Launch Turi Create

# %%
import turicreate as tc
from turicreate import SArray

# %% [markdown]
# # Load house sales data

# %%
sales = tc.SFrame('~/venv/Week2/home_data.sframe')

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %% [markdown]
# # Explore

# %%
tc.visualization.set_target(target="browser")
x = SArray(sales["sqft_living"])
y=SArray(sales["price"])
tc.visualization.scatter(x, y)
# Out:
# <html>                 <body>                     <iframe style="border:0;margin:0" width="920" height="770" srcdoc='<html lang="en">                         <head>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega/5.4.0/vega.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-embed/4.0.0/vega-embed.js"></script>                             <script src="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.js"></script>                             <link rel="stylesheet" type="text/css" href="https://cdnjs.cloudflare.com/ajax/libs/vega-tooltip/0.5.1/vega-tooltip.min.css">                             <style>                             .vega-actions > a{                                 color:white;                                 text-decoration: none;                                 font-family: "Arial";                                 cursor:pointer;                                 
# ...

# %%
tc.show(sales[1:5000]['sqft_living'],sales[1:5000]['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray

# %% [markdown]
# # Simple regression model that predicts price from square feet

# %%
training_set, test_set = sales.random_split(.8,seed=0)
#Use tab for shortcuts to autofill
#set seed to get the same output when multiple runs are done

# %% [markdown]
# ## train simple regression model

# %%
sqft_model = tc.linear_regression.create(training_set,target='price',features=['sqft_living'])
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Evaluate the quality of our model

# %%
print (test_set['price'].mean())
# Out:
# 543054.0425632538

# %%
print (sqft_model.evaluate(test_set))
# Out:
# {'max_error': 4127723.430263007, 'rmse': 255229.11040969685}

# %% [markdown]
# # Explore model a little further

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+--------------------+--------------------+
# |     name    | index |       value        |       stderr       |
# +-------------+-------+--------------------+--------------------+
# | (intercept) |  None | -50287.04478206474 | 5078.582653373803  |
# | sqft_living |  None | 283.8790307906024  | 2.2288281321569654 |
# +-------------+-------+--------------------+--------------------+
# [2 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(test_set['sqft_living'],test_set['price'],'.',
        test_set['sqft_living'],sqft_model.predict(test_set),'-')

# %% [markdown]
# # Explore other features of the data

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
tc.visualization.set_target(target="browser")
sales[my_features].show()
# Out:
# Materializing SFrame

# %%
tc.show(sales['zipcode'],sales['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray

# %% [markdown]
# # Build a model with these additional features

# %%
my_features_model = tc.linear_regression.create(training_set,target='price',features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Compare simple model with more complex one

# %%
print (my_features)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']

# %%
print (sqft_model.evaluate(test_set))
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 4127723.430263007, 'rmse': 255229.11040969685}
# {'max_error': 3135858.0835363497, 'rmse': 180440.39998685798}

# %% [markdown]
# # Apply learned models to make predictions

# %%
house1 = sales[sales['id']=='5309101200']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000.0 |   4.0    |    2.25   |
# +------------+---------------------------+----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="http://blue.kingcounty.com/Assessor/eRealProperty/MediaHandler.aspx?Media=2916871">

# %%
print (house1['price'])
# Out:
# [620000.0, ... ]

# %%
print (sqft_model.predict(house1))
# Out:
# [631022.629115381]

# %%
print (my_features_model.predict(house1))
# Out:
# [729002.5957890621]

# %% [markdown]
# ## Prediction for a second house, a fancier one

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000.0 |   5.0    |    4.25   |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="https://ssl.cdn-redfin.com/photo/1/bigphoto/302/734302_0.jpg">

# %%
print (sqft_model.predict(house2))
# Out:
# [1266911.6580863306]

# %%
print (my_features_model.predict(house2))
# Out:
# [1236653.9518202743]

# %% [markdown]
# ## Prediction for a super fancy home

# %%
bill_gates = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/26/Residence_of_Bill_Gates.jpg">

# %%
#Turicreate needs sframes as input 
print (my_features_model.predict(tc.SFrame(bill_gates)))
# Out:
# [15088300.206101455]

# %%
#Question1 
#Average house price
pincode = sales[sales['zipcode']=="98039"]
#print (sales[['zipcode']=="98039"])
print (pincode['price'].mean())
# Out:
# 2160606.5999999996

# %%
#Question 2
#Logic filtering
print (sales.num_rows())
den = sales.num_rows()
# Out:
# 21613

# %%
filtern1 = sales[(sales['sqft_living']<=4000) & (sales['sqft_living']>=2000)]
print (filtern1.num_rows())
num = filtern1.num_rows()
# Out:
# 9221

# %%
fraction = (num/den)
fraction
# Out:
# 0.4266413732475825

# %%
#Question 3
#Regression Model with multiple more features

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house
'grade', # measure of quality of construction
'waterfront', # waterfront property
'view', # type of view
'sqft_above', # square feet above ground
'sqft_basement', # square feet in basement
'yr_built', # the year built
'yr_renovated', # the year renovated
'lat', 'long', # the lat-long of the parcel
'sqft_living15', # average sq.ft. of 15 nearest neighbors 
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
print (advanced_features)
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode', 'condition', 'grade', 'waterfront', 'view', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

# %%
#training_set, test_set = sales.random_split(.8,seed=0)
my_feature_model = tc.linear_regression.create(training_set, target='price', features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
print (my_feature_model.evaluate(test_set))
# Out:
# {'max_error': 3182948.6574095273, 'rmse': 180703.8847885125}

# %%
print (test_set['price'].mean())
# Out:
# 543054.0425632538

# %%
advanced_feature_model = tc.linear_regression.create(training_set, target='price', features=advanced_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 18
# Number of unpacked features : 18
# Number of coefficients    : 87
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %%
print (advanced_feature_model.evaluate(test_set))
# Out:
# {'max_error': 3141071.343973412, 'rmse': 155101.77004836922}

# %%
print (my_feature_model.evaluate(test_set)['rmse'] - advanced_feature_model.evaluate(test_set)['rmse'])
# Out:
# 25602.114740143297
